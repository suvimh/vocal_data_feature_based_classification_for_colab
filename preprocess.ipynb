# %% [markdown]
# # Preprocess Data to Focus on Specific Modalities / Sources

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# !pip install ipython-autotime
# %load_ext autotime
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 10.2 MB/s eta 0:00:00
# ...
# time: 578 µs (started: 2024-07-22 08:07:32 +00:00)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
# time: 31 s (started: 2024-07-22 08:07:32 +00:00)

# %%
from google.colab import files
import os
import shutil

# Copy scripts from Google Drive to Colab
shutil.copy('/content/drive/MyDrive/THESIS/classifiers/scripts/data_preprocess.py', '/content/data_preprocess.py')
# Out:
# '/content/data_preprocess.py'
# time: 3.26 s (started: 2024-07-22 08:08:03 +00:00)

# %%
from data_preprocess import preprocess_data
# Out:
# time: 896 ms (started: 2024-07-22 08:08:07 +00:00)

# %% [markdown]
# ### Extract computer source and EMG PZT sources

# %%
data_in_path = '/content/drive/MyDrive/THESIS/thesis_data/THESIS_DATA/data_p14.csv'
data_out_path = '/content/drive/MyDrive/THESIS/classifiers/data/data_p14_preprocessed.csv'

preprocess_data(data_in_path, data_out_path, audio_source='computer', video_source='computer', bio_sources=['respiration_1','emg_1'], individual_model=True)
# Out:
# time: 39.3 s (started: 2024-07-22 08:09:31 +00:00)
